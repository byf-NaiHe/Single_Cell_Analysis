# %%
import re
import numpy as np
import pandas as pd
import scanpy as sc
import scvelo as scv
import cellrank as cr
from scipy import sparse
from anndata import AnnData
import matplotlib.cm as cm
import os

sc.set_figure_params(dpi=100, color_map='viridis', fontsize=6)
sc.settings.verbosity=2
sc.settings.n_jobs=16
cr.settings.verbosity = 2
scv.settings.verbosity = 3
sc.logging.print_versions()

stype = "CD4"
oDir = os.path.abspath("./OUT_FigS26")

if not os.path.exists(oDir):
    os.makedirs(oDir)
os.chdir(oDir)
# Out:
# WARNING: If you miss a compact list, please try `print_header`!
# -----
# anndata     0.7.5
# scanpy      1.6.1
# sinfo       0.3.1
# -----
# PIL                 8.1.0
# anndata             0.7.5
# backcall            0.1.0
# cellrank            1.1.0
# cffi                1.12.3
# colorama            0.4.1
# cycler              0.10.0
# cython_runtime      NA
# dateutil            2.8.0
# decorator           4.4.0
# docrep              0.3.1
# future_fstrings     NA
# get_version         2.1
# google              NA
# h5py                2.10.0
# igraph              0.7.1
# importlib_metadata  0.17
# ipykernel           5.1.1
# ipython_genutils    0.2.0
# ipywidgets          7.6.3
# jedi                0.13.3
# joblib              0.13.2
# kiwisolver          1.1.0
# legacy_api_wrap     1.2
# leidenalg           0.7.0
# llvmlite            0.35.0
# louvain             0.6.1
# matplotlib          3.4.1
# mpl_toolkits        NA
# natsort             6.0.0
# numba               0.52.0
# numexpr             2.6.9
# numpy               1.19.5
# packaging           19.0
# pandas              1.1.5
# parso               0.4.0
# pexpect             4.7.0
# pickleshare         0.7.5
# pkg_resources       NA
# progressbar         3.53.1
# prompt_toolkit      2.0.9
# ptyprocess          0.6.0
# pygam               0.8.0
# pygments            2.4.2
# pyparsing           2.4.0
# python_utils        NA
# pytz                2019.1
# scanpy              1.6.1
# scipy               1.4.1
# scvelo              0.2.3
# setuptools_scm      NA
# simplejson          3.16.0
# sinfo               0.3.1
# six                 1.12.0
# sklearn             0.24.0
# statsmodels         0.10.1
# storemagic          NA
# tables              3.5.1
# threadpoolctl       2.1.0
# tornado             6.0.2
# traitlets           4.3.2
# typing_extensions   NA
# wcwidth             NA
# wrapt               1.12.1
# yaml                5.1.2
# zipp                NA
# zmq                 18.0.1
# -----
# IPython             7.5.0
# jupyter_client      5.2.4
# jupyter_core        4.4.0
# notebook            5.7.8
# -----
# Python 3.7.3 (default, Mar 27 2019, 22:11:17) [GCC 7.3.0]
# Linux-4.15.0-156-generic-x86_64-with-debian-buster-sid
# 64 logical CPU cores, x86_64
# -----
# Session information updated at 2021-11-23 14:53

# %%
adata = sc.read(f"{oDir}/../../data/velo/adata_mini_{stype}.h5ad")

# %%
## add cellInfo
cellInfo = pd.read_csv(f"{oDir}/../../data/metaInfo/{stype}.miniInfo.txt.gz", compression='gzip', sep="\t", header=0, index_col=0)
cellInfo = cellInfo.loc[list(adata.obs_names), [not bool(re.match('RNA_', i)) for i in cellInfo.columns] ]
adata.obs = cellInfo
#
adata.obs['cancerType'] = [re.sub('\\..*', '', i) for i in np.array(adata.obs.dataset)]

# %%
## add pseudotime (and subset)
pseudotime = pd.read_csv(f"{oDir}/../../data/metaInfo/{stype}_Treg.monocle3_pseudotime.txt.gz",
                       compression="gzip", sep="\t", header=0, index_col=0)
over = list(set(pseudotime.index) & set(adata.obs_names))
pseudotime = pseudotime.loc[over, ]
adata = adata[over,]
adata.obs['Monocle3_pseudotime'] = pseudotime.pseudotime
# Out:
# Trying to set attribute `.obs` of view, copying.

# %%
## add embedding
redim1 = pd.read_csv(f"{oDir}/../../data/metaInfo/{stype}.umap_harmony.txt.gz", compression="gzip", sep="\t", header=0, index_col=0)
over = list(set(redim1.index) & set(adata.obs_names))
adata=adata[over,]
redim1 = redim1.loc[over,:]
#
adata.obsm['X_UMAP'] = np.array(redim1)

# %%
## add colSet
adata.obs["meta.cluster"] = adata.obs["meta.cluster"].astype('category')
color = pd.read_csv(f"{oDir}/../../data/metaInfo/color_meta.cluster_.txt.gz", compression="gzip", sep="\t", header=None, index_col=0)
color_used = list(color.loc[adata.obs["meta.cluster"].cat.categories,1])
adata.uns['meta.cluster_colors'] = color_used

# %% [markdown]
# # scVelo

# %%
scv.pp.filter_and_normalize(adata, min_shared_cells=30, log=True)
# Out:
# Filtered out 25216 genes that are detected in less than 30 cells (shared).
# WARNING: Did not normalize X as it looks processed already. To enforce normalization, set `enforce=True`.
# WARNING: Did not normalize spliced as it looks processed already. To enforce normalization, set `enforce=True`.
# WARNING: Did not normalize unspliced as it looks processed already. To enforce normalization, set `enforce=True`.
# Logarithmized X.

# %%
adata.X.shape
# Out:
# (874, 8478)

# %%
## read cycling genes
cell_cycle_genes = [x.strip() for x in open(f"{oDir}/../../data/external/regev_lab_cell_cycle_genes.txt")]
s_genes = cell_cycle_genes[:43]
g2m_genes = cell_cycle_genes[43:]
cell_cycle_genes = [x for x in cell_cycle_genes if x in adata.var_names]

## compute score
sc.tl.score_genes_cell_cycle(adata, s_genes=s_genes, g2m_genes=g2m_genes)

#plot
scv.settings.set_figure_params('scvelo', dpi=100)
adata_cc_genes = adata[:, cell_cycle_genes]
sc.tl.pca(adata_cc_genes)
sc.pl.pca_scatter(adata_cc_genes, color='phase')

## regress and scale
sc.pp.regress_out(adata, ['S_score', 'G2M_score'])
sc.pp.scale(adata)

#plot
adata_cc_genes = adata[:, cell_cycle_genes]
sc.tl.pca(adata_cc_genes)
sc.pl.pca_scatter(adata_cc_genes, color='phase')
# Out:
# calculating cell cycle phase
# computing score 'S_score'
# WARNING: genes are not in var_names and ignored: ['FEN1', 'GINS2', 'MLF1IP', 'CDC45', 'CHAF1B', 'E2F8']
#     finished (0:00:00)
# computing score 'G2M_score'
# WARNING: genes are not in var_names and ignored: ['BIRC5', 'FAM64A', 'CDC20', 'TTK', 'CDC25C', 'PSRC1', 'GAS2L3', 'CENPA']
#     finished (0:00:00)
# computing PCA
#     with n_comps=50
#     finished (0:00:00)
# ... storing 'dataset' as categorical
# ... storing 'dataset.tech' as categorical
# ... storing 'cancerType' as categorical
# ... storing 'phase' as categorical
# regressing out ['S_score', 'G2M_score']
#     sparse input is densified and may lead to high memory use
# ... storing 'dataset' as categorical
# ... storing 'dataset.tech' as categorical
# ... storing 'cancerType' as categorical
# ... storing 'phase' as categorical
#     finished (0:00:01)
# computing PCA
#     with n_comps=50
#     finished (0:00:00)

# %%
## clean some genes
ignoreGenes = pd.read_csv(f"{oDir}/../../data/external/all.gene.ignore.df.txt.gz", compression='gzip', sep="\t", header=0, index_col=0)
print(ignoreGenes.head())
flag = [not i in list(ignoreGenes['geneSymbol']) for i in list(adata.var.index)]
adata = adata[:,flag]
#
flag = [not bool(re.match('^RP[LS]', i)) for i in adata.var_names]
adata = adata[:,flag]
# Out:
#                  geneSymbol attr.chr     attr.beg     attr.end attr.strand  \
# geneID
# ENSG00000143061       IGSF3        1  116574399.0  116667755.0           -
# ENSG00000276674  IGKV1OR1-1        1  144085628.0  144086098.0           +
# ENSG00000085552       IGSF9        1  159927039.0  159945604.0           -
# ENSG00000162729       IGSF8        1  160091340.0  160098943.0           -
# ENSG00000163395       IGFN1        1  201190825.0  201228952.0           +
#
#                         geneType display.name      seu.id
# geneID
# ENSG00000143061   protein_coding        IGSF3       IGSF3
# ENSG00000276674  IG_V_pseudogene   IGKV1OR1-1  IGKV1OR1-1
# ENSG00000085552   protein_coding        IGSF9       IGSF9
# ENSG00000162729   protein_coding        IGSF8       IGSF8
# ENSG00000163395   protein_coding        IGFN1       IGFN1

# %%
scv.pp.moments(adata, n_pcs=30, n_neighbors=30)
# Out:
# computing PCA
#     with n_comps=30
#     finished (0:00:00)
# computing neighbors
#     finished (0:00:02) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:01) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)

# %%
scv.tl.recover_dynamics(adata, n_jobs=32, n_top_genes=500)
scv.tl.velocity(adata, mode='dynamical', min_r2=None)
scv.tl.velocity_graph(adata)
# Out:
# recovering dynamics (using 32/64 cores)
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=500.0), HTML(value='')))
#     finished (0:00:07) --> added
#     'fit_pars', fitted parameters for splicing dynamics (adata.var)
# computing velocities
#     finished (0:00:00) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)
# computing velocity graph
#     finished (0:00:00) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %%
scv.settings.set_figure_params('scvelo', dpi=200)
scv.pl.velocity_embedding_grid(adata, basis='UMAP',color='meta.cluster',arrow_size=1.5, arrow_length=2,  arrow_color="#D2691E",
                               legend_loc='right margin',legend_fontsize=5,
                               save=f".{stype}_Treg.umap.pdf", figsize=(7,6))
# Out:
# computing velocity embedding
#     finished (0:00:00) --> added
#     'velocity_UMAP', embedded velocity vectors (adata.obsm)
# saving figure to file ./figures/scvelo_.CD4_Treg.umap.pdf

# %%
scv.settings.set_figure_params('scvelo', dpi=200)
scv.pl.velocity_embedding_grid(adata, basis='UMAP',color='Monocle3_pseudotime',arrow_size=1.5, arrow_length=2,  arrow_color="#D2691E",
                               legend_loc='right margin',legend_fontsize=5,
                               save=f".{stype}_Treg.umap_M3pseudotime.pdf", figsize=(7,6))
# Out:
# saving figure to file ./figures/scvelo_.CD4_Treg.umap_M3pseudotime.pdf

# %%
adata.write(f"{oDir}/{stype}_Treg.velo.h5ad")

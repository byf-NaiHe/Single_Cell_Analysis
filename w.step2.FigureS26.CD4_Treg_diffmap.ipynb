# %%
import os
import re
import numpy as np            
import pandas as pd           
import scanpy as sc
import bbknn
import matplotlib.pyplot as plt
sc.set_figure_params(dpi=100, color_map='viridis', fontsize=6)
sc.settings.verbosity=2
sc.settings.n_jobs=16
sc.logging.print_versions()

stype = "CD4"
oDir = os.path.abspath("./OUT_FigS26")

if not os.path.exists(oDir):
    os.makedirs(oDir)
os.chdir(oDir)
# Out:
# WARNING: If you miss a compact list, please try `print_header`!
# -----
# anndata     0.7.5
# scanpy      1.6.1
# sinfo       0.3.1
# -----
# PIL                 8.1.0
# anndata             0.7.5
# annoy               NA
# backcall            0.1.0
# bbknn               NA
# cffi                1.12.3
# colorama            0.4.1
# cycler              0.10.0
# cython_runtime      NA
# dateutil            2.8.0
# decorator           4.4.0
# future_fstrings     NA
# get_version         2.1
# google              NA
# h5py                2.10.0
# igraph              0.7.1
# importlib_metadata  0.17
# ipykernel           5.1.1
# ipython_genutils    0.2.0
# ipywidgets          7.6.3
# jedi                0.13.3
# joblib              0.13.2
# kiwisolver          1.1.0
# legacy_api_wrap     1.2
# leidenalg           0.7.0
# llvmlite            0.35.0
# louvain             0.6.1
# matplotlib          3.4.1
# mpl_toolkits        NA
# natsort             6.0.0
# numba               0.52.0
# numexpr             2.6.9
# numpy               1.19.5
# packaging           19.0
# pandas              1.1.5
# parso               0.4.0
# pexpect             4.7.0
# pickleshare         0.7.5
# pkg_resources       NA
# prompt_toolkit      2.0.9
# ptyprocess          0.6.0
# pycparser           2.19
# pygments            2.4.2
# pyparsing           2.4.0
# pytz                2019.1
# scanpy              1.6.1
# scipy               1.4.1
# setuptools_scm      NA
# simplejson          3.16.0
# sinfo               0.3.1
# six                 1.12.0
# sklearn             0.24.0
# storemagic          NA
# tables              3.5.1
# tornado             6.0.2
# traitlets           4.3.2
# typing_extensions   NA
# umap                0.3.10
# wcwidth             NA
# yaml                5.1.2
# zipp                NA
# zmq                 18.0.1
# -----
# IPython             7.5.0
# jupyter_client      5.2.4
# jupyter_core        4.4.0
# notebook            5.7.8
# -----
# Python 3.7.3 (default, Mar 27 2019, 22:11:17) [GCC 7.3.0]
# Linux-4.15.0-156-generic-x86_64-with-debian-buster-sid
# 64 logical CPU cores, x86_64
# -----
# Session information updated at 2021-11-23 14:17

# %%
adata = sc.read(f"{oDir}/../../data/expression/{stype}/integration/{stype}.expr.txt.gz", delimiter="\t",first_column_names=True)
# Out:
# WARNING: Your filename has more than two extensions: ['.expr', '.txt', '.gz'].
# Only considering the two last: ['.txt', '.gz'].
# WARNING: Your filename has more than two extensions: ['.expr', '.txt', '.gz'].
# Only considering the two last: ['.txt', '.gz'].

# %%
## add cellInfo
cellInfo = pd.read_csv(f"{oDir}/../../data/metaInfo/{stype}.miniInfo.txt.gz", compression="gzip", sep="\t", header=0, index_col=0)
cellInfo = cellInfo.loc[list(adata.obs_names), [not bool(re.match('RNA_', i)) for i in cellInfo.columns] ]
adata.obs = cellInfo
#
adata.obs['cancerType'] = [re.sub('\\..*', '', i) for i in np.array(adata.obs.dataset)]

# %%
## subset
keep_clus = ['CD4.c18.Treg.RTKN2','CD4.c19.Treg.S1PR1','CD4.c20.Treg.TNFRSF9','CD4.c21.Treg.OAS1']
flag = [i in keep_clus for i in adata.obs.loc[:,'meta.cluster']]
adata = adata[flag,]

# %%
## hvg
sc.pp.highly_variable_genes(adata, n_top_genes=2500, subset=False)

## pca
sc.tl.pca(adata, n_comps=30)
sc.pl.pca_variance_ratio(adata)
# Out:
# If you pass `n_top_genes`, all cutoffs are ignored.
# extracting highly variable genes
#     finished (0:00:00)
# /data2/qss/01.software/miniconda3/lib/python3.7/site-packages/scanpy/preprocessing/_highly_variable_genes.py:208: RuntimeWarning: invalid value encountered in log
#   dispersion = np.log(dispersion)
# Trying to set attribute `.uns` of view, copying.
# computing PCA
#     on highly variable genes
#     with n_comps=30
#     finished (0:00:00)

# %% [markdown]
# # Run

# %%
sc.pp.neighbors(adata, n_pcs=30)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 30
#     finished (0:00:01)

# %%
## diffusion map
sc.tl.diffmap(adata, n_comps=10)
# Out:
# computing Diffusion Maps using n_comps=10(=n_dcs)
# computing transitions
#     finished (0:00:00)
#     eigenvalues of transition matrix
#     [1.         0.94943315 0.9005386  0.89435947 0.87741494 0.8675266
#      0.863371   0.84353334 0.8325241  0.8290217 ]
#     finished (0:00:00)

# %%
sc.set_figure_params(dpi=160, color_map='viridis', fontsize=8)
sc.pl.embedding(adata, basis='diffmap', color=['meta.cluster'],
                legend_loc='right margin', legend_fontsize=5,
                save=f".{stype}_Treg.pdf")
# Out:
# ... storing 'dataset' as categorical
# ... storing 'dataset.tech' as categorical
# ... storing 'ClusterID.pca' as categorical
# ... storing 'ClusterID.harmony' as categorical
# ... storing 'meta.cluster' as categorical
# ... storing 'meta.cluster.coarse' as categorical
# ... storing 'cancerType' as categorical
# WARNING: saving figure to file figures/diffmap.CD4_Treg.pdf

# %%
## DPT
#Find the stem cell with the smallest DC1 value to act as root for the diffusion pseudotime and compute DPT
Tn_mask = np.isin(adata.obs['meta.cluster'], ['CD4.c18.Treg.RTKN2','CD4.c19.Treg.S1PR1'])
min_stem_id = np.argmin(adata.obsm['X_diffmap'][Tn_mask, 1])
root_id = np.arange(len(Tn_mask))[Tn_mask][min_stem_id]
adata.uns['iroot'] = root_id
#
sc.tl.dpt(adata)
# Out:
# computing Diffusion Pseudotime using n_dcs=10
#     finished (0:00:00)

# %%
sc.pl.diffmap(adata, color='dpt_pseudotime', color_map="hot_r", save=f"_pseudotime.{stype}_Treg.pdf")
# Out:
# WARNING: saving figure to file figures/diffmap_pseudotime.CD4_Treg.pdf

# %%
## save
adata.write(f"{oDir}/{stype}_Treg.sc.h5ad")
diff = pd.DataFrame(adata.obsm['X_diffmap'], index=adata.obs_names)
diff.to_csv(f"{oDir}/{stype}_Treg.diffMap.txt", sep="\t")
adata.obs.loc[:,["meta.cluster","dpt_pseudotime"]].to_csv(f"{oDir}/{stype}_Treg.dpt_pseudotime.txt", sep="\t")
